# %% [markdown]
# # Q(1)
#
# ##
#
# Let $\Omega$ be a disk of radius $R=10$ centered at the origin:
# $$\Omega=\{(x,y)\in \mathbb{R}^2 : x^2+y^2\le 10^2\}.$$
# Let $A$ be the event that a chosen point lies within $1$ unit of the boundary. This means the point's distance from the center is between $9$ and $10$.
# $$A=\left\{(x,y)\in \Omega : 9\le \sqrt{x^2+y^2}\le 10\right\}.$$
#
#
#
# ## Model 1: Uniform distribution with respect to area
# In this model, the probability of an event is proportional to its area.
#
# -   Total area of disk: $\pi(10)^2 = 100\pi$.
# -   Area of event $A$ (annulus between radii 9 and 10): $\pi(10)^2 - \pi(9)^2 = 100\pi - 81\pi = 19\pi$.
# -   Probability $P(A) = \frac{\text{Area of A}}{\text{Total Area}} = \frac{19\pi}{100\pi} = \boxed{\frac{19}{100}}$.
#
# ## Model 2: Uniform distribution of the radius
# In this model, the radius $r$ is chosen uniformly from $[0, 10]$, and the angle $\theta$ uniformly from $[0, 2\pi)$. The probability depends only on the length of the radial interval.
#
# -   Total sample space for radius: Interval $[0, 10]$, length $10$.
# -   Favorable outcomes for event $A$: Radius in interval $[9, 10]$, length $1$.
# -   Probability $P(A) = \frac{\text{Favorable Length}}{\text{Total Length}} = \frac{1}{10} = \boxed{\frac{1}{10}}$.
#
# ## Why the two answers differ
# The phrase “chosen at random” is ambiguous. The two models represent different probability measures on the same geometric set.
#
# -   **Area-uniform model:** Points near the boundary are more likely because the area there is greater.
# -   **Radius-uniform model:** Each radial interval of the same length is equally likely, regardless of the area it covers.
#
# ## Practical Implication: Dart-throwing Analogy
#
# -   **Area-uniform model:** Corresponds to physical randomness, like throwing darts at a board without bias. The empirical probability would be close to $\frac{19}{100}$.
# -   **Radius-uniform model:** Corresponds to an artificial two-step sampling (first choose radius, then angle). This does not represent ordinary geometric randomness.
#
# > In most real-world scenarios, “randomly chosen point in a disk” is best modeled by the uniform distribution on area.

# %% [markdown]
# # Q(2)

# %% [markdown]
# **Preliminary geometric fact**
#
# Let the circle be
#
# $$
# x^2+y^2=1.
# $$
#
# The side length of the inscribed equilateral triangle is
#
# $$
# \sqrt{3}.
# $$
#
# A chord is longer than $\sqrt{3}$ if and only if its perpendicular distance from the center is less than $1/2$.
#
#
# **Proof:**
#
# If a chord is at distance $r\in[0,1]$ from the center, then half its length is the horizontal leg of a right triangle with hypotenuse $1$ and other leg $r$. Hence the chord length is
#
# $$
# L(r)=2\sqrt{1-r^2}.
# $$
#
# We want
#
# $$
# L(r)>\sqrt{3}.
# $$
#
# This is equivalent to
#
# $$
# r<\frac12.
# $$
#
# So the event of interest is precisely
#
# $$
# A=\{ \text{distance of chord from center} < 1/2\}.
# $$     This model is often described more simply as:
#
# * choose one endpoint uniformly on the circumference,
# * then choose the other endpoint uniformly on the circumference.
#
# By rotational symmetry, we may fix the first endpoint and choose the second uniformly.
#
#
#
# **Probability space**
#
# Let
#
# $$
# \Omega_1=[0,\pi]
# $$
#
# with Borel sigma-algebra
#
# $$
# \mathfrak A_1=\mathfrak B([0,\pi]),
# $$
#
# and probability measure
#
# $$
# P_1(E)=\frac{\lambda(E)}{\pi},
# \qquad E\in\mathfrak A_1,
# $$
#
# where $\lambda$ is Lebesgue measure.
#
# Interpret $\theta\in[0,\pi]$ as the smaller central angle subtended by the chord.
#
#
#
# **Event**
#
# A chord subtending angle $\theta$ has length
#
# $$
# L(\theta)=2\sin(\theta/2).
# $$
#
# We want
#
# $$
# L(\theta)>\sqrt{3}.
# $$
#
# Thus
#
# $$
# 2\sin(\theta/2)>\sqrt{3}
# $$
#
# $$
# \sin(\theta/2)>\frac{\sqrt{3}}{2}.
# $$
#
# Since $\theta/2\in[0,\pi/2]$, this is equivalent to
#
# $$
# \theta/2>\pi/3
# \quad\Longleftrightarrow\quad
# \theta>2\pi/3.
# $$
#
# So
#
# $$
# A_1=(2\pi/3,\pi].
# $$
#
#
#
# **Probability**
#
# Therefore
#
# $$
# P_1(A_1)=\frac{\pi-2\pi/3}{\pi}=\frac{1}{3}.
# $$
#
# So under Model-1,
#
# $$
# \boxed{P_1(A_1)=\frac13}.
# $$     This model is:
#
# * choose a radius,
# * choose a point uniformly along that radius,
# * draw the chord perpendicular to the radius through that point.
#
# Equivalently, the distance of the chord from the center is chosen uniformly in $[0,1]$.
#
#
#
# **Probability space**
#
# Let
#
# $$
# \Omega_2=[0,1]
# $$
#
# with sigma-algebra
#
# $$
# \mathfrak A_2=\mathfrak B([0,1]),
# $$
#
# and probability measure
#
# $$
# P_2(E)=\lambda(E),
# \qquad E\in\mathfrak A_2,
# $$
#
# since $\lambda([0,1])=1$.
#
# Interpret $r\in[0,1]$ as the perpendicular distance from the center to the chord.
#
#
#
# **Event**
#
# From the preliminary calculation, the chord is longer than the side of the inscribed equilateral triangle exactly when
#
# $$
# r<1/2.
# $$
#
# So
#
# $$
# A_2=[0,1/2).
# $$
#
#
#
# **Probability**
#
# Hence
#
# $$
# P_2(A_2)=\lambda([0,1/2))=\frac12.
# $$
#
# So under Model 2,
#
# $$
# \boxed{P_2(A_2)=\frac12}.
# $$    This model is:
#
# * choose the midpoint of the chord uniformly from the whole disk,
# * draw the unique chord having that midpoint.
#
# Since every chord is uniquely determined by its midpoint, this defines a probability law on chords.
#
#
#
# **Probability space**
#
# Let
#
# $$
# \Omega_3=\{(x,y)\in\mathbb R^2:x^2+y^2\le 1\}
# $$
#
# be the closed unit disk, with sigma-algebra
#
# $$
# \mathfrak A_3=\mathfrak B(\Omega_3).
# $$
#
# Define $P_3$ by normalized area:
#
# $$
# P_3(E)=\frac{\lambda_2(E)}{\pi},
# \qquad E\in\mathfrak A_3,
# $$
#
# where $\lambda_2$ is planar Lebesgue measure.
#
# Interpret $(x,y)$ as the midpoint of the chord.
#
#
#
# **Event**
#
# If the midpoint is $(x,y)$, then its distance from the center is
#
# $$
# r=\sqrt{x^2+y^2}.
# $$
#
# As shown above, the chord is longer than $\sqrt{3}$ exactly when
#
# $$
# r<1/2.
# $$
#
# Thus
#
# $$
# A_3=\{(x,y)\in\Omega_3:x^2+y^2<1/4\}.
# $$
#
# This is the disk of radius (1/2).
#
#
#
# **Probability**
#
# Therefore
#
# $$
# P_3(A_3)=\frac{\text{area of disk of radius }1/2}{\text{area of unit disk}}
# =\frac{\pi(1/2)^2}{\pi}
# =\frac14.
# $$
#
# So under Model 3,
#
# $$
# \boxed{P_3(A_3)=\frac14}.
# $$

# %% [markdown]
# # Q(8)

# %% [markdown]
# The sample space is
#
# $$
# \Omega=\{BB,BG,GB,GG\},
# $$
#
# where the first letter denotes the older child and the second the younger.
#
# Each outcome has probability $1/4$.
#
# The condition “at least one is a girl” excludes only $BB$, so the remaining possible outcomes are
#
# $$
# \{GG,BG,GB\}.
# $$
#
# Among these three equally likely outcomes, only one is $GG$. Therefore
#
# $$
# P(\text{both girls}\mid \text{at least one girl})=\frac{1}{3}.
# $$
#
# So the answer is
#
# $$
# \boxed{\frac13}.
# $$
#
# Many people first guess $1/2$, but that corresponds to a different question.
#
# For example, if we are told:
#
# > The older child is a girl,
#
# then the possible outcomes are
#
# $$
# \{GG,GB\},
# $$
#
# and so
#
# $$
# P(\text{both girls}\mid \text{older child is a girl})=\frac12.
# $$

# %% [markdown]
# # Q(9)

# %% [markdown]
# Here is a full sample answer in the same style.
#
# 1. The probability space is
#
# $$
# \Omega=\{G_1,G_2,D_1,D_2\},
# $$
#
# $$
# \mathfrak F=\mathfrak P(\Omega),
# $$
#
# and the probability measure $P$ is defined by
#
# $$
# P(\{G_1\})=0.50,\qquad P(\{G_2\})=0.20,\qquad P(\{D_1\})=0.10,\qquad P(\{D_2\})=0.20.
# $$
#
# Since
#
# $$
# 0.50+0.20+0.10+0.20=1,
# $$
#
# this is a valid probability measure.
#
# 2. The random variable $X$ records whether the item is good or defective:
#
# $$
# X(G_1)=0,\qquad X(G_2)=0,\qquad X(D_1)=1,\qquad X(D_2)=1.
# $$
#
# Thus the inverse images are
#
# $$
# X^{-1}(\{0\})=\{G_1,G_2\},
# $$
#
# and
#
# $$
# X^{-1}(\{1\})=\{D_1,D_2\}.
# $$
#
# Hence
#
# $$
# \sigma(X)=\left\{\varnothing,\Omega,\{G_1,G_2\},\{D_1,D_2\}\right\}.
# $$
#
# 3. The random variable $Y$ records both quality and machine:
#
# $$
# Y(G_1)=1,\qquad Y(G_2)=2,\qquad Y(D_1)=3,\qquad Y(D_2)=4.
# $$
#
# Since each outcome is assigned a distinct value, $Y$ distinguishes every point of $\Omega$. Therefore
#
# $$
# \sigma(Y)=\mathfrak P(\Omega).
# $$
#
# Explicitly,
#
# $$
# \sigma(Y)=\left\{\varnothing,\{G_1\},\{G_2\},\{D_1\},\{D_2\},\{G_1,G_2\},\{G_1,D_1\},\ldots,\Omega\right\}.
# $$
#
# 4. Since $\sigma(Y)=\mathfrak P(\Omega)$, we have
#
# $$
# \sigma(X)\subseteq \sigma(Y).
# $$
#
# Thus $Y$ contains more information than $X$.
#
# 5. The marginal distribution of $X$ is
#
# $$
# P(X=0)=P(\{G_1,G_2\})=0.50+0.20=0.70,
# $$
#
# and
#
# $$
# P(X=1)=P(\{D_1,D_2\})=0.10+0.20=0.30.
# $$
#
# So
#
# $$
# P(X=0)=0.70,\qquad P(X=1)=0.30.
# $$
#
# 6. The marginal distribution of $Y$ is
#
# $$
# P(Y=1)=0.50,\qquad P(Y=2)=0.20,\qquad P(Y=3)=0.10,\qquad P(Y=4)=0.20.
# $$
#
# 7. The joint probabilities are
#
# $$
# P(X=0,Y=1)=0.50,\qquad P(X=0,Y=2)=0.20,
# $$
#
# $$
# P(X=1,Y=3)=0.10,\qquad P(X=1,Y=4)=0.20,
# $$
#
# and all others are zero.
#
# 8. The conditional probabilities are
#
# $$
# P(X=1\mid Y=3)=1,\qquad P(X=1\mid Y=4)=1.
# $$
#
# Also
#
# $$
# P(Y=3\mid X=1)=\frac{0.10}{0.30}=\frac{1}{3},\qquad
# P(Y=4\mid X=1)=\frac{0.20}{0.30}=\frac{2}{3}.
# $$
#
# 9. Conditioning on $Y$ gives more precise information than conditioning on $X$. For example,
#
# $$
# P(X=1\mid Y=3)=1,
# $$
#
# but
#
# $$
# P(Y=3\mid X=1)=\frac{1}{3},\qquad P(Y=4\mid X=1)=\frac{2}{3}.
# $$
#
# 10. The $\sigma$-algebra $\sigma(X)$ contains only information about whether the item is good or defective, while $\sigma(Y)$ contains full information about the outcome. Hence $\sigma(Y)$ is finer than $\sigma(X)$.
#
# A concise conclusion is:
#
# > The two random variables are defined on the same sample space but generate different $\sigma$-algebras. Since
# > $$
# > \sigma(X)\subseteq \sigma(Y),
# > $$
# > the variable $Y$ carries more information than $X$.

# %% [markdown]
# Using natural logarithms, the Shannon entropy is
#
# $$
# H(Z)=-\sum_z P(z)\ln P(z).
# $$
#
# so
#
# $$
# H(X)=-(0.70\ln 0.70+0.30\ln 0.30),
# $$
#
#
# $$
# H(Y)=-(0.50\ln 0.50+0.20\ln 0.20+0.10\ln 0.10+0.20\ln 0.20).
# $$
#
# Thus
# $$
# H(X)\approx 0.61086,
# $$
#
# and
#
# $$
# H(Y)\approx 1.22061.
# $$
#
# For the joint entropy,
#
# $$
# H(X,Y)= -\sum_{x,y} P(x,y)\ln P(x,y),
# $$
#
# so only the nonzero terms contribute:
#
# $$
# H(X,Y)=-(0.50\ln 0.50+0.20\ln 0.20+0.10\ln 0.10+0.20\ln 0.20).
# $$
#
# Therefore
#
# $$
# H(X,Y)\approx 1.22061.
# $$
#
# Since each value of $Y$ determines $X$ exactly,
#
# $$
# H(X\mid Y)=0.
# $$
#
# Also,
#
# $$
# H(Y\mid X)=H(X,Y)-H(X),
# $$
#
# so
#
# $$
# H(Y\mid X)\approx 1.22061-0.61086=0.60975.
# $$
#
# So in natural logarithm form:
#
# $$
# H(X)\approx 0.61086
# $$
#
# $$
# H(Y)\approx 1.22061
# $$
#
# $$
# H(X,Y)\approx 1.22061
# $$
#
# $$
# H(X\mid Y)=0
# $$
#
# $$
# H(Y\mid X)\approx 0.60975
# $$

# %% [markdown]
# # Q(10)

# %% [markdown]
# 1. The probability space is
#
# $$
# \Omega=\mathbb R^2, \qquad \mathfrak F=\mathfrak B(\mathbb R^2),
# $$
#
# where $\mathfrak B(\mathbb R^2)$ is the Borel $\sigma$-algebra.
#
# A point $\omega\in\Omega$ has the form
#
# $$
# \omega=(t,p),
# $$
#
# where $t$ is the standardized temperature deviation and $p$ is the standardized pressure deviation.
#
# The probability measure $P$ is defined by
#
# $$
# f_{T,P}(t,p)=\frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right), \qquad (t,p)\in\mathbb R^2.
# $$
#
# Thus for any Borel set $A\subseteq\mathbb R^2$,
#
# $$
# P(A)=\iint_A f_{T,P}(t,p)\,dt\,dp.
# $$
#
# Since $T\sim N(0,1)$ and $P\sim N(0,4)$ are independent, this is a valid probability measure.
#
# ---
# #
# #
#
# 2. The random variable $X$ is defined by
#
# $$
# X(t,p)=t.
# $$
#
# Thus $X$ records only the temperature deviation.
#
# The $\sigma$-algebra generated by $X$ is
#
# $$
# \sigma(X)=\left\{X^{-1}(B): B\in\mathfrak B(\mathbb R)\right\}.
# $$
#
# Since
#
# $$
# X^{-1}(B)=\{(t,p)\in\mathbb R^2:t\in B\}=B\times \mathbb R,
# $$
#
# we obtain
#
# $$
# \sigma(X)=\{B\times\mathbb R: B\in\mathfrak B(\mathbb R)\}.
# $$
#
#
#
#
# ---
#
#
#
# 3. The random variable $Y$ is defined by
#
# $$
# Y(t,p)=(t,p).
# $$
#
# Since $Y$ is the identity map,
#
# $$
# \sigma(Y)=\mathfrak B(\mathbb R^2),
# $$
#
# because for every Borel set $A\subseteq\mathbb R^2$,
#
# $$
# Y^{-1}(A)=A.
# $$
#
# ---
#
# 4. Since every set of the form $B\times\mathbb R$ is Borel,
#
# $$
# \sigma(X)\subset \sigma(Y).
# $$
#
# The inclusion is strict. For example,
#
# $$
# [-1,1]\times[-2,2]\in\sigma(Y)
# $$
#
# but not in $\sigma(X)$.
#
# ---
#
# 5. The marginal density of $X$ is
#
# $$
# f_X(x)=\int_{-\infty}^{\infty} f_{T,P}(x,p)\,dp
# $$
#
# so
#
# $$
# f_X(x)=\int_{-\infty}^{\infty}\frac{1}{4\pi}
# \exp\left(-\frac{x^2}{2}-\frac{p^2}{8}\right)\,dp.
# $$
#
# Using
#
# $$
# \int_{-\infty}^{\infty}\frac{1}{\sqrt{8\pi}}
# \exp\left(-\frac{p^2}{8}\right)\,dp=1,
# $$
#
# we obtain
#
# $$
# f_X(x)=\frac{1}{\sqrt{2\pi}}\exp\left(-\frac{x^2}{2}\right).
# $$
#
# Thus
#
# $$
# X\sim N(0,1).
# $$
#
# ---
#
# 6. The density of $Y$ is
#
# $$
# f_Y(t,p)=\frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right).
# $$
#
# Thus $Y$ is a bivariate normal vector with independent components.
#
#
# ---
# 7. Probabilities:
#
# $$
# P(X\leq 0)=\frac{1}{2}, \qquad P(X>1)=1-\Phi(1)\approx 0.1587.
# $$
#
# $$
# P\bigl(Y\in(-\infty,0]\times\mathbb R\bigr)=\frac{1}{2}.
# $$
#
# $$
# P\bigl(Y\in[-1,1]\times[-2,2]\bigr)
# = P(-1\leq T\leq 1)\,P(-2\leq P\leq 2).
# $$
#
# $$
# = (2\Phi(1)-1)^2 \approx 0.466.
# $$
#
# ----
#
# 8. Conditional distribution:
#
# $$
# X \mid Y=(t,p) \sim \delta_t.
# $$
#
# ---
#
# 9. Conditional distribution:
#
# $$
# Y \mid X=t \sim (t,P), \quad P\sim N(0,4).
# $$
#
# $$
# P_{Y|X=t} = \delta_t \otimes \mathcal N(0,4).
# $$
#
# $$
# f_{Y|X}((u,v)\mid t)
# = \delta_t(u)\,\frac{1}{\sqrt{8\pi}}e^{-v^2/8}.
# $$
#
# ---
#
# 10. Conditioning on $X$ gives only temperature; conditioning on $Y$ gives both temperature and pressure.
#
# ---
#
# 11. Define
#
# $$
# \pi_1(t,p)=t.
# $$
#
# Then
#
# $$
# X=\pi_1\circ Y, \qquad \sigma(X)\subseteq\sigma(Y).
# $$
#
# ---
#
# 12. Visualization idea:
#
# - contour plot of $f_Y$
# - plot of $f_X$
# - vertical strips $B\times\mathbb R$
# - rectangles like $[-1,1]\times[-2,2]$
#
# ---
#
# 13. Entropy:
#
# $$
# h(X)=\frac{1}{2}\ln(2\pi e)\approx 1.4189.
# $$
#
#
# ---
# 14. Entropy:
#
# $$
# h(Y)=\frac{1}{2}\ln(2\pi e)+\frac{1}{2}\ln(8\pi e)
# = \ln(2\pi e)+\ln 2 \approx 3.5310.
# $$
#
#
# ---
# 15. Conditional entropy:
#
# $$
# h(Y|X)=\frac{1}{2}\ln(8\pi e)\approx 2.1121.
# $$
#
#
# ---
# 16. Since $X$ is determined by $Y$,
#
# $$
# h(X|Y)=-\infty.
# $$
